# %%
from bs4 import BeautifulSoup

f = open("testfile.txt", encoding="utf8")

soup = BeautifulSoup(f.read(), 'html.parser')

# %%
result = (soup.get_text()) 
print(type(result))

result = result.replace('\\n', '')
result = result.replace('\\t', '')

print(result)
# Out:
# <class 'str'>
# ...
